# %%
'''
class - 02
'''

a = 10
b = 16
# I am your single line comment
"""
    So I am your multiline comment :)
"""
c = a + b
print(c)
# Out:
# 26

# %%
"""
    DATA TYPES

    box - variables
    type of item - data type
"""

# PRIMITIVE DATA TYPES (fundamental) - INTEGERS, FLOAT, STRING, BOOLEAN, NONE, COMPLEX
# box - contain only 1 value

# INTEGERS
age = 10
print(age)

# FLOAT - decimals
pi = 3.14
print(pi)

# STRING - words / sentences / characters
name = "Omraj"
hobby = "I like to play badminton"
favAlpha = "a"
print(name, hobby, favAlpha)

# BOOLEAN - True, False
passed = True
print(passed)

# None - nothing
car = None
print(car)

# Complex - real + imaginary
z = 2 + 3j

PI = 3.14          # it's value should not change - caution
print ( 2 * PI * 10)

# DERIVED DATATYPES - these are made up of primitive datatypes
# box - contains more than 1 value

# LIST - array (different language)
fruits = ["apple", "mango", "grapes", "grapes", 1, 2,3,4, True]
print(fruits)

# TUPLE - FIXED LIST - can't add, remove
favFruits = ("mango", "guava", "guava")
print(favFruits)

# SET - unique items
numbers = {1,2,3,3,4,4,4,5,5,5}
print(numbers)

# FROZENSET - FIXED SET - can't add, remove
frozen = frozenset([1,2,3,3,4,4,4,4])
print(frozen)

# DICTIONARY - key: value - map
studentMarks = {
    "Geeta": 95,
    "Ritwik": 94,
    "Swaroop": True
}
print(studentMarks)
# Out:
# 10
# 3.14
# Omraj I like to play badminton a
# True
# None
# 62.800000000000004
# ['apple', 'mango', 'grapes', 'grapes', 1, 2, 3, 4, True]
# ('mango', 'guava', 'guava')
# {1, 2, 3, 4, 5}
# frozenset({1, 2, 3, 4})
# {'Geeta': 95, 'Ritwik': 94, 'Swaroop': True}

# %%
'''
class 03 - Operators

Type of operator
1. Unary - 1 operand
2. Binary - 2 operand
3. Tertiary - 3 operand

'''

# BINARY
# a = 5
# b = 10
# c = a + b 
# a, b are operands
# '+' is an operator

# UNARY
d = -a
# a is an operand
# '-' is an operator
# print(a)
# print(d)

'''
ARITHEMETIC OPERATORS
+ - * / // % **
'''
# a = 5
# b = 8
# print("#### ARITHEMETIC OPERATORS ####")
# print( a+b )
# print( a-b )
# print( a*b )
# print( b/a )
# print( b//a )  # floor
# # floor of 1.6 - 1
# # ceil of 1.6 - 2
# print( b%a )  # remainder
# print( 5**3 )  # power 5 ^ 3

'''
COMPARSION OPERATORS -> True/False
'''
# a = 5
# b = 8
# print("#### COMPARISON OPERATORS ####")
# print(a == b)
# print(a < b)
# print(a > b)
# print(a != b)  # ! -> not
# print(a <= b)
# print(a >= b)

'''
ASSIGNMENT OPERATORS
'''
# a = 10
# print(a)
# a += 5 # a = a + 5
# print(a)
# a /= 3
# print(a)
# a *= 10
# print(a)
# a %= 3  # a = a % 3
# print(a)
# a **= 5  # a = a ** 5 = a ^ 5 = 2 ^ 5 = 32
# print(a)
# a //= 15  # a = a // 15 -> a / 15 = 32 / 15 = 2.13 ~ floor = 2
# print(a)

'''
LOGICAL OPERATORS
and, or, not

True - 1
False - 0

and - multiply
or - addition
'''
# print(not True)
# print(not False)
# print(False and False)
# print(False and True)
# print(True and True)
# print(True and False)
# print(False or False)
# print(False or True)
# print(True or True)
# print(True or False)
# print(10 > 5 and 10 < 9)

'''
MEMBERSHIP & IDENTITY OPERATOR
'''
# print( "a" in "cat" )
# print( "b" in "cat" )
# print( "b" not in "cat" )
# print( "c" not in "cat" )
# a = 5
# b = a
# c = 5
# print( a is b )
# print( a is c )

# x = [1,2,3]
# y = x
# z = [1,2,3]
# print(x is y)
# print(x is z)


'''
BITWISE OPERATOR
works on bits (0,1)
'''
# print(5 & 3)
# print(5 | 3)
# print(5 ^ 3)
# print(5 << 1)  # left shift (bits)
# print(5 >> 1)  # right shift (bits)
# Out:
# 1
# 7
# 6
# 10
# 2

# %%
'''
CLASS 04 - CONDITIONALS & LOOPS
'''

# HOW TO TAKE INPUT IN THE PROGRAM?
# num = int(input("Enter any number: "))
# print(num * 10)

# GRADING SYSTEM
# marks = int(input("Enter your marks: "))
# if marks >= 90:
#     print("GRADE: A")
# elif marks >= 80:
#     print("GRADE: B")
# elif marks >= 70:
#     print("GRADE: C")
# else:
#     print("GRADE: D")

# TRAFFIC LIGHT
# light = input("Enter traffic light color (red/yellow/green): ")
# if light == "red":
#     print("STOP 🛑")
# elif light == "yellow":
#     print("GET REDDY ⚠️")
# elif light == "green":
#     print("Go 🟢")
# else:
#     print("INVALID INPUT ❌")

# LOOPS - repeating, iterative
# for loop
nums = [45, 10, 36, 50, 77, 2, 6, 8, 49, 31, 18, 00, 50, 5, 10]

# PRINT nums
# for num in nums:
#     print(num * 2)

# totalSum = 0
# for num in nums:
#     totalSum = totalSum + num

# COMPUTERS DON'T LIE
# print(totalSum)

# range(1,10) = [1,2,3,4,5,6,7,8,9]
# # tables
# num = int(input("Enter a number"))
# num = 5
# for i in range(1,11):
#     print(num * i)

# WHILE LOOPS
# ATM Pin verification
# correct_pin = "1234"
# attempt = ""
# while attempt != correct_pin:
#     attempt = input("Enter your PIN: ")
# print("Access Granted ✅")

# PRINT VALUES
# when while loop break? Ans - when the condition is false
# a = 50
# while a <= 100:
#     print(a)
#     a = a + 1

# BREAK & CONTINUE
# break - break the loop
# items = ["pen", "notebook", "eraser", "pencil"]
# for item in items:
#     if item == "eraser":
#         break
#     print(item)

# continue - continue the loop
# for i in range(1,6):
#     if i == 3:
#         continue
#     print(i)

# IGNORE THIS AS OF NOW TO RUN - IT WILL THROW YOU AN ERROR
# for user in users:
#     if (user.balance < 100)
#         continue
#     print("Amazing offer")

a = 1000
b = 1000
print(a is b)

a = 10
b = 10
print(a is b)
# Out:
# False
# True

# %%
'''
class 05 - STRINGS
sequence of characters enclosed in quotes
'''

# name1 = 'Shyam'
# name2 = "Om"
# multiline strings
# name3 = '''
#     Omraj 
#     Sharma'''
# print(name1, name2, name3)

# name = "Omraj"
# print(name[4])
# print(name[-2])  # value from the end (not all languages support this)

# SLICING
# name = "LEARN BAY"
# print(name[0:5])
# print(name[:5])
# print(name[6:])

# COUNT
# name = "LEARN BAY"
# print(name.count('A'))
# print(name.count('x'))

# STRIP
# name = "    LEARN BAY    "
# print(name)            # '    LEARN BAY    '
# print(name.strip())    # 'LEARN BAY'
# print(name.lstrip())   # 'LEARN BAY    '
# print(name.rstrip())   # '    LEARN BAY'
# name = "----LEARN BAY----"
# print(name)
# print(name.strip('-'))

# INDEX V/S FIND
# name = 'LEARNBAY'
# print(name.index('A'))
# # print(name.index('x'))    # character not present in string, it throws ValueError
# print(name.find('A'))
# print(name.find('x'))       # -1

# STARTWITH, ENDWITH
# name = 'I am a student at learnbay'
# print(name.startswith('learn'))
# print(name.endswith('learnbay'))

# FORMAT
# names = ['Ankit', 'Imra', 'Surendra']
# template = '''
# Hi {} sir/mam,
# Welcome to our amazing platform and enjoy this day.
# '''
# for name in names:
#     print(template.format(name))

# name = "Omraj Sharma"
# phone = "7503047413"
# email = '''
# Hi {} sir/madam
# We're love to welcome you on our place. Please comfirm your phone number {}
# '''
# print(email.format(name, phone))

# UPPER
# name = "Om"
# print(name.upper())

# LOWER
# print(name.lower())

# SWAPCASE
# print(name.swapcase())

# REPLACE
favouriteFood = "apples are sweet"
print(favouriteFood)
print(favouriteFood.replace("apples", ""))

# RFIND
# name = "learnbay"
# print(name.find('a'))    # 2
# print(name.rfind('a'))   # 6
# print(name.rfind('x'))   # -1

# RINDEX
# name = "learnbay"
# print(name.rindex('x'))  # ValueError

# TITLE
# name = "omraj"
# print(name.title())

# ISAPLHA
# name = "learnbay"
# print(name.isalpha())
# name = "learnbay123"
# print(name.isalpha())

# ISALNUM - a-z, A-Z, 0-9
# name = "learnbay"
# print(name.isalnum())
# name = "learnbay123"
# print(name.isalnum())
# name = "learnbay 123"
# print(name.isalnum())
# name = "1234567890"
# print(name.isalnum())

# ISUPPER
# name = "LEARNBAY"
# print(name.isupper())

# ISLOWER
# name = "LEARNBAY"
# print(name.islower())

# ISTITLE
# name = "Omraj"
# print(name.istitle())
# name = "omraj"
# print(name.istitle())

# JOIN
# names = ["Jyoti", "Surendra", "Sucheta"]
# print("-".join(names))

# ISSPACE
# name = "           "
# print(name.isspace())
# name = "     s      "
# print(name.isspace())

# ISDIGIT
# name = "123"
# print(name.isdigit())
# print("1/2".isdigit())
# print("1.23".isdigit())
# print("456".isdigit())
# print("²³".isdigit())

# ISDECIMAL - strict isdigit
# print("²³".isdecimal())

# ISNUMERIC - all characters including fraction, superscripts, roman numerals
# print("12".isnumeric())
# print("Ⅻ".isnumeric())
# print("¼".isnumeric())
# print("123abc".isnumeric())

# ISPRINTABLE - if all characters are printable (not like \n, \t)
# print("hello\n world \t on earth".isprintable())
# print("omraj".isprintable())
# Out:
# apples are sweet
#  are sweet

# %%
'''
CLASS 06 - LIST
Collection of items

features:
1. Ordered
2. Changeable
3. Duplicates OK
4. Any type
'''
nums = [1,3,5,7,9,11]  # nums - list of integers
names = ["Amit", "Sucheta", "Swaroop"]  # names - list of strings
ans = [True, False, True, False, False]  # ans - list of boolean
mix_list = [1, "apple", True, 2.5]  # only valid in few language

# INDEXING
# print(mix_list[1])
# print(mix_list[2])
# print(mix_list[-4])

# SLICING
# print(nums[0:5:3])

# NESTED LIST - LIST OF LIST
# mobile = [
#     ["Iphone", "Samsung"],
#     ["Oneplus", "Nothing"]
# ]
# print(mobile[0][1])

# LIST METHODS

# APPEND
# print(names)
# names.append("Swamy")
# print(names)

# INSERT
# names.insert(1, "Omraj")
# print(names)

# REMOVES - first match of {value}
# names.remove("Omraj")
# print(names)

# POP - remove last item
# names.pop()
# print(names)
# names.pop(1)
# print(names)

# adding more values to test
# names.append("Sucheta")
# names.append("Shudhanshu")
# names.append("Omraj")
# names.append("Fardin")
# print(names)

# REVERSE
# names.reverse()
# print(names)

# COUNT
# print(names.count("Fardin"))

# INDEX - first index, ValueError
# print(names.index("Omraj"))

# COPY
# names = ["Om", "Shyam"]
# print(names)
# names2 = names.copy()  # deep copy - real copy
# names.pop()
# print(names2)

# TUPLE - IMMUTABLE LIST
# t = (1,2,3,2,1,9)
# print(t.count(3))
# print(t.index(9))

'''
ASSIGNMENT
'''
# Create a list of your 5 favourite fruits
fruits=["Apple","Cherry","Grapes","Watermelon","Avacado"]
print(fruits)

# Add a new fruit to the end of the list
fruits.append("Lichi")
print(fruits)

# Insert a new fruit at position 2
fruits.insert(2, "Guava")
print(fruits)

# Slice of the list to get first 3 fruits
print(fruits[:3])

# Find the maximum and minimum in a list
nums = [43,65,2,4,6,43,2,34,23,45,7,87,43]

minNum = 100000
maxNum = 0

for num in nums:
    if (num < minNum):
        minNum = num
    if (num > maxNum):
        maxNum = num

print(maxNum, minNum)

# Find the sum of all the elements in the list
totalSum = 0
for num in nums:
    totalSum += num

print(totalSum)

# Check if the list is sorted or not (ascending)
# todo - tomorrow

# arr = [1,4,18,10,12]
# ans = True
# for i in range(0, len(arr) - 1):
#     if ( arr[i] > arr[i+1] ):
#         ans = False
#         break

# print(ans)
# Out:
# ['Apple', 'Cherry', 'Grapes', 'Watermelon', 'Avacado']
# ['Apple', 'Cherry', 'Grapes', 'Watermelon', 'Avacado', 'Lichi']
# ['Apple', 'Cherry', 'Guava', 'Grapes', 'Watermelon', 'Avacado', 'Lichi']
# ['Apple', 'Cherry', 'Guava']
# 87 2
# 404
# False

# %%
import copy

'''
DICTIONARY - collection of key-value pairs

PROPERTY
1. Unordered
2. Mutable (you can change)
3. Index by keys
4. Unique
'''
# laptop = {
#     "company": "apple",
#     "model": "m2",
#     "memory": 256,
# }
# print(laptop)

# ASSIGNMENT - create a dictionary of your phone - milestone 1
# phone = {
#     "company": "",
#     "ram": "",
#     "memory": "",   
# }

# ACCESS IN DICTIONARY
# print(laptop["model"])
# print(laptop["camera"])  # KeyError

# GET
# print( laptop.get("model") )
# print( laptop.get("camera") )
# print( laptop.get("camera", "4 mega pixel") )

# ITERATION ON DICTIONARY
# employee = {
#     "name": "Omraj",
#     "company": "ABC",
#     "area": "Green Glen",
#     "city": "Bangalore",
#     "state": "Karnataka",
#     "age": "10",
#     "pin": "560103",
#     "phone": "7503047413",
#     "email": "omraj7413@gmail.com"
# }

# for k in employee:
#     print(k, " : ", employee[k][:2])

# NESTED DICTIONARY
# employee1 = {
#     "name": "Omraj",
#     "phone": "7503047413",
#     "email": "omraj7413@gmail.com",
#     "company": "ABC",
#     "address": {
#         "area": "Green Glen",
#         "city": "Bangalore",
#         "state": "Karnataka",
#         "age": "10",
#         "pin": "560103",
#     }
# }

# ACCESS IN NESTED DICTIONARIES
# print( employee1["address"]["city"] )

# SHALLOW COPY
# employee2 = employee1
# employee1["name"] = "Om"
# employee2["name"] = "Shyam"
# print( employee1["name"] )

# DEEP COPY
# employee2 = copy.deepcopy(employee1)
# employee1["name"] = "Om"
# employee2["name"] = "Shyam"
# print( employee1["name"] )
# print( employee2["name"] )

# KEYS()
# print(employee2.keys())

# VALUES()
# print(employee2.values())

# ITEMS
# for ke, va in employee.items():
#     print(ke, va)

# UPDATE
# car = {
#     "engine": 1200,
#     "color": "black"
# }
# print(car)
# car.update({"mileage": 20, "model": "kia"})
# print(car)
# car.update({"color": "red", "model": "mahindra"})
# print(car)

# POP
# car = {
#     "engine": 1200,
#     "color": "black"
# }
# print(car)
# engine = car.pop("engine")
# print(engine)
# print(car)
# car.pop("something")  # KeyError

# CLEAR
# car = {
#     "engine": 1200,
#     "color": "black"
# }
# print(car)
# car.clear()
# print(car)

# COPY - shallow copy
# car2 = car.copy

# EMPLOYEE FILTER - (salary < 7500) - expected result dictionary {"Rajesh": 4500, "Ramesh": 7400}
employee = {
    "Ramu": 10000,
    "Shyamu": 7500,
    "Rajesh": 4500,
    "Nitin": 2900,
    "Ramesh": 7400
}

# result = {}

# for k, v in employee.items():
#     if (v < 7500):
#         result[k] = v

# print(result)

print(employee.values())
# Out:
# dict_values([10000, 7500, 4500, 2900, 7400])

# %%
'''
FUNCTIONS
'''

'''
REPEATING THE CODE
- Code duplicate
- Hard maintain
- Low reusability
'''
# a = 5
# b = 10 
# print(a+b)  # task

# x = 7
# y = 3
# print(x+y)

# p = 5
# q = 7
# print(p+q)

# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")

'''
BENEFITS OF FUNCTIONS/METHOD - workers
- ORGANISE CODE
- REUSABLE
- READABILITY

DRY prinple - Don't repeat yourself

create
use/call

Restaurant 
- Guard - Greet()
- Receptionist - check for booking, align available table
- Waiter - take order, serve order
- Cleaner - clean the table and nearby
- Chef - cook
- Manager - manage
'''

# def greet():
#     print("Hello sir/madam, Welcome to learnbay. Keep learing")

# greet()

# def reception(members):
#     if members <= 2:
#         print("provide a couple table")
#     elif members <= 4:
#         print("provide a family table")
#     elif members <= 10:
#         print("provide a party table")
#     else:
#         print("provide party hall")

# reception(2)
# reception(5)
# reception(1)
# reception(20)
# reception(3)

# def waiter(requirement):
#     if requirement == "water":
#         return "A bisleri water bottle"
#     if requirement == "menu":
#         return "Starts, Main course and Drinks Menu"
#     if requirement == "tissue":
#         return "Warm water with lime"
#     else :
#         return "Sorry sir/madam"

# response = waiter("tissue")
# print(response)
# print( waiter("Cold drink") )

# ARGUMENT - values we pass inside a function - in waiter function the argument is "requirement"

# DEFAULT ARGUMENTS
# def greet(name):
#     print("Hi " + name + " sir/madam, welcome to our restaurant. We believe you will love our hospitality.")

# greet("Omraj")
# greet("Anupam")
# greet()  # error - greet() missing 1 required positional argument: 'name'

# Guest is a default argument
# def greet(name = "Guest"):
#     print("Hi " + name + " sir/madam, welcome to our restaurant. We believe you will love our hospitality.")

# greet()
# greet("Shyam")
# greet()

# MULTIPLE ARGUMENT
# def addNumber(a, b):
#     print(a+b)

# addNumber(2,5)
# addNumber(6,3)
# addNumber(2,2)

# ARGUMENT ORDER
# def addNumber(a, b):
#     print(a)
#     print(b)
#     # print(a+b)

# addNumber(b=5, a=2)  # not recommentded

# VARIABLE LENGTH ARGUMENTS
# def addNumbers(*nums):
#     currentSum = 0
#     for num in nums:
#         currentSum += num
#     print(currentSum)

# addNumbers(1,2,3,4,5)

# ASSIGNMENT - PRACTICE THESE EXAMPLES
# Out:
# 15
# 3
# 0

# %%
'''
class 09 - MODULES
'''
