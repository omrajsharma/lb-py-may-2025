# %%
'''
class - 02
'''

a = 10
b = 16
# I am your single line comment
"""
    So I am your multiline comment :)
"""
c = a + b
print(c)
# Out:
# 26

# %%
"""
    DATA TYPES

    box - variables
    type of item - data type
"""

# PRIMITIVE DATA TYPES (fundamental) - INTEGERS, FLOAT, STRING, BOOLEAN, NONE, COMPLEX
# box - contain only 1 value

# INTEGERS
age = 10
print(age)

# FLOAT - decimals
pi = 3.14
print(pi)

# STRING - words / sentences / characters
name = "Omraj"
hobby = "I like to play badminton"
favAlpha = "a"
print(name, hobby, favAlpha)

# BOOLEAN - True, False
passed = True
print(passed)

# None - nothing
car = None
print(car)

# Complex - real + imaginary
z = 2 + 3j

PI = 3.14          # it's value should not change - caution
print ( 2 * PI * 10)

# DERIVED DATATYPES - these are made up of primitive datatypes
# box - contains more than 1 value

# LIST - array (different language)
fruits = ["apple", "mango", "grapes", "grapes", 1, 2,3,4, True]
print(fruits)

# TUPLE - FIXED LIST - can't add, remove
favFruits = ("mango", "guava", "guava")
print(favFruits)

# SET - unique items
numbers = {1,2,3,3,4,4,4,5,5,5}
print(numbers)

# FROZENSET - FIXED SET - can't add, remove
frozen = frozenset([1,2,3,3,4,4,4,4])
print(frozen)

# DICTIONARY - key: value - map
studentMarks = {
    "Geeta": 95,
    "Ritwik": 94,
    "Swaroop": True
}
print(studentMarks)
# Out:
# 10
# 3.14
# Omraj I like to play badminton a
# True
# None
# 62.800000000000004
# ['apple', 'mango', 'grapes', 'grapes', 1, 2, 3, 4, True]
# ('mango', 'guava', 'guava')
# {1, 2, 3, 4, 5}
# frozenset({1, 2, 3, 4})
# {'Geeta': 95, 'Ritwik': 94, 'Swaroop': True}

# %%
'''
class 03 - Operators

Type of operator
1. Unary - 1 operand
2. Binary - 2 operand
3. Tertiary - 3 operand

'''

# BINARY
# a = 5
# b = 10
# c = a + b 
# a, b are operands
# '+' is an operator

# UNARY
d = -a
# a is an operand
# '-' is an operator
# print(a)
# print(d)

'''
ARITHEMETIC OPERATORS
+ - * / // % **
'''
# a = 5
# b = 8
# print("#### ARITHEMETIC OPERATORS ####")
# print( a+b )
# print( a-b )
# print( a*b )
# print( b/a )
# print( b//a )  # floor
# # floor of 1.6 - 1
# # ceil of 1.6 - 2
# print( b%a )  # remainder
# print( 5**3 )  # power 5 ^ 3

'''
COMPARSION OPERATORS -> True/False
'''
# a = 5
# b = 8
# print("#### COMPARISON OPERATORS ####")
# print(a == b)
# print(a < b)
# print(a > b)
# print(a != b)  # ! -> not
# print(a <= b)
# print(a >= b)

'''
ASSIGNMENT OPERATORS
'''
# a = 10
# print(a)
# a += 5 # a = a + 5
# print(a)
# a /= 3
# print(a)
# a *= 10
# print(a)
# a %= 3  # a = a % 3
# print(a)
# a **= 5  # a = a ** 5 = a ^ 5 = 2 ^ 5 = 32
# print(a)
# a //= 15  # a = a // 15 -> a / 15 = 32 / 15 = 2.13 ~ floor = 2
# print(a)

'''
LOGICAL OPERATORS
and, or, not

True - 1
False - 0

and - multiply
or - addition
'''
# print(not True)
# print(not False)
# print(False and False)
# print(False and True)
# print(True and True)
# print(True and False)
# print(False or False)
# print(False or True)
# print(True or True)
# print(True or False)
# print(10 > 5 and 10 < 9)

'''
MEMBERSHIP & IDENTITY OPERATOR
'''
# print( "a" in "cat" )
# print( "b" in "cat" )
# print( "b" not in "cat" )
# print( "c" not in "cat" )
# a = 5
# b = a
# c = 5
# print( a is b )
# print( a is c )

# x = [1,2,3]
# y = x
# z = [1,2,3]
# print(x is y)
# print(x is z)


'''
BITWISE OPERATOR
works on bits (0,1)
'''
# print(5 & 3)
# print(5 | 3)
# print(5 ^ 3)
# print(5 << 1)  # left shift (bits)
# print(5 >> 1)  # right shift (bits)
# Out:
# 1
# 7
# 6
# 10
# 2

# %%
'''
CLASS 04 - CONDITIONALS & LOOPS
'''

# HOW TO TAKE INPUT IN THE PROGRAM?
# num = int(input("Enter any number: "))
# print(num * 10)

# GRADING SYSTEM
# marks = int(input("Enter your marks: "))
# if marks >= 90:
#     print("GRADE: A")
# elif marks >= 80:
#     print("GRADE: B")
# elif marks >= 70:
#     print("GRADE: C")
# else:
#     print("GRADE: D")

# TRAFFIC LIGHT
# light = input("Enter traffic light color (red/yellow/green): ")
# if light == "red":
#     print("STOP 🛑")
# elif light == "yellow":
#     print("GET REDDY ⚠️")
# elif light == "green":
#     print("Go 🟢")
# else:
#     print("INVALID INPUT ❌")

# LOOPS - repeating, iterative
# for loop
nums = [45, 10, 36, 50, 77, 2, 6, 8, 49, 31, 18, 00, 50, 5, 10]

# PRINT nums
# for num in nums:
#     print(num * 2)

# totalSum = 0
# for num in nums:
#     totalSum = totalSum + num

# COMPUTERS DON'T LIE
# print(totalSum)

# range(1,10) = [1,2,3,4,5,6,7,8,9]
# # tables
# num = int(input("Enter a number"))
# num = 5
# for i in range(1,11):
#     print(num * i)

# WHILE LOOPS
# ATM Pin verification
# correct_pin = "1234"
# attempt = ""
# while attempt != correct_pin:
#     attempt = input("Enter your PIN: ")
# print("Access Granted ✅")

# PRINT VALUES
# when while loop break? Ans - when the condition is false
# a = 50
# while a <= 100:
#     print(a)
#     a = a + 1

# BREAK & CONTINUE
# break - break the loop
# items = ["pen", "notebook", "eraser", "pencil"]
# for item in items:
#     if item == "eraser":
#         break
#     print(item)

# continue - continue the loop
# for i in range(1,6):
#     if i == 3:
#         continue
#     print(i)

# IGNORE THIS AS OF NOW TO RUN - IT WILL THROW YOU AN ERROR
# for user in users:
#     if (user.balance < 100)
#         continue
#     print("Amazing offer")

a = 1000
b = 1000
print(a is b)

a = 10
b = 10
print(a is b)
# Out:
# False
# True

# %%
'''
class 05 - STRINGS
sequence of characters enclosed in quotes
'''

# name1 = 'Shyam'
# name2 = "Om"
# multiline strings
# name3 = '''
#     Omraj 
#     Sharma'''
# print(name1, name2, name3)

# name = "Omraj"
# print(name[4])
# print(name[-2])  # value from the end (not all languages support this)

# SLICING
# name = "LEARN BAY"
# print(name[0:5])
# print(name[:5])
# print(name[6:])

# COUNT
# name = "LEARN BAY"
# print(name.count('A'))
# print(name.count('x'))

# STRIP
# name = "    LEARN BAY    "
# print(name)            # '    LEARN BAY    '
# print(name.strip())    # 'LEARN BAY'
# print(name.lstrip())   # 'LEARN BAY    '
# print(name.rstrip())   # '    LEARN BAY'
# name = "----LEARN BAY----"
# print(name)
# print(name.strip('-'))

# INDEX V/S FIND
# name = 'LEARNBAY'
# print(name.index('A'))
# # print(name.index('x'))    # character not present in string, it throws ValueError
# print(name.find('A'))
# print(name.find('x'))       # -1

# STARTWITH, ENDWITH
# name = 'I am a student at learnbay'
# print(name.startswith('learn'))
# print(name.endswith('learnbay'))

# FORMAT
# names = ['Ankit', 'Imra', 'Surendra']
# template = '''
# Hi {} sir/mam,
# Welcome to our amazing platform and enjoy this day.
# '''
# for name in names:
#     print(template.format(name))

# name = "Omraj Sharma"
# phone = "7503047413"
# email = '''
# Hi {} sir/madam
# We're love to welcome you on our place. Please comfirm your phone number {}
# '''
# print(email.format(name, phone))

# UPPER
# name = "Om"
# print(name.upper())

# LOWER
# print(name.lower())

# SWAPCASE
# print(name.swapcase())

# REPLACE
favouriteFood = "apples are sweet"
print(favouriteFood)
print(favouriteFood.replace("apples", ""))

# RFIND
# name = "learnbay"
# print(name.find('a'))    # 2
# print(name.rfind('a'))   # 6
# print(name.rfind('x'))   # -1

# RINDEX
# name = "learnbay"
# print(name.rindex('x'))  # ValueError

# TITLE
# name = "omraj"
# print(name.title())

# ISAPLHA
# name = "learnbay"
# print(name.isalpha())
# name = "learnbay123"
# print(name.isalpha())

# ISALNUM - a-z, A-Z, 0-9
# name = "learnbay"
# print(name.isalnum())
# name = "learnbay123"
# print(name.isalnum())
# name = "learnbay 123"
# print(name.isalnum())
# name = "1234567890"
# print(name.isalnum())

# ISUPPER
# name = "LEARNBAY"
# print(name.isupper())

# ISLOWER
# name = "LEARNBAY"
# print(name.islower())

# ISTITLE
# name = "Omraj"
# print(name.istitle())
# name = "omraj"
# print(name.istitle())

# JOIN
# names = ["Jyoti", "Surendra", "Sucheta"]
# print("-".join(names))

# ISSPACE
# name = "           "
# print(name.isspace())
# name = "     s      "
# print(name.isspace())

# ISDIGIT
# name = "123"
# print(name.isdigit())
# print("1/2".isdigit())
# print("1.23".isdigit())
# print("456".isdigit())
# print("²³".isdigit())

# ISDECIMAL - strict isdigit
# print("²³".isdecimal())

# ISNUMERIC - all characters including fraction, superscripts, roman numerals
# print("12".isnumeric())
# print("Ⅻ".isnumeric())
# print("¼".isnumeric())
# print("123abc".isnumeric())

# ISPRINTABLE - if all characters are printable (not like \n, \t)
# print("hello\n world \t on earth".isprintable())
# print("omraj".isprintable())
# Out:
# apples are sweet
#  are sweet

# %%
'''
CLASS 06 - LIST
Collection of items

features:
1. Ordered
2. Changeable
3. Duplicates OK
4. Any type
'''
nums = [1,3,5,7,9,11]  # nums - list of integers
names = ["Amit", "Sucheta", "Swaroop"]  # names - list of strings
ans = [True, False, True, False, False]  # ans - list of boolean
mix_list = [1, "apple", True, 2.5]  # only valid in few language

# INDEXING
# print(mix_list[1])
# print(mix_list[2])
# print(mix_list[-4])

# SLICING
# print(nums[0:5:3])

# NESTED LIST - LIST OF LIST
# mobile = [
#     ["Iphone", "Samsung"],
#     ["Oneplus", "Nothing"]
# ]
# print(mobile[0][1])

# LIST METHODS

# APPEND
# print(names)
# names.append("Swamy")
# print(names)

# INSERT
# names.insert(1, "Omraj")
# print(names)

# REMOVES - first match of {value}
# names.remove("Omraj")
# print(names)

# POP - remove last item
# names.pop()
# print(names)
# names.pop(1)
# print(names)

# adding more values to test
# names.append("Sucheta")
# names.append("Shudhanshu")
# names.append("Omraj")
# names.append("Fardin")
# print(names)

# REVERSE
# names.reverse()
# print(names)

# COUNT
# print(names.count("Fardin"))

# INDEX - first index, ValueError
# print(names.index("Omraj"))

# COPY
# names = ["Om", "Shyam"]
# print(names)
# names2 = names.copy()  # deep copy - real copy
# names.pop()
# print(names2)

# TUPLE - IMMUTABLE LIST
# t = (1,2,3,2,1,9)
# print(t.count(3))
# print(t.index(9))

'''
ASSIGNMENT
'''
# Create a list of your 5 favourite fruits
fruits=["Apple","Cherry","Grapes","Watermelon","Avacado"]
print(fruits)

# Add a new fruit to the end of the list
fruits.append("Lichi")
print(fruits)

# Insert a new fruit at position 2
fruits.insert(2, "Guava")
print(fruits)

# Slice of the list to get first 3 fruits
print(fruits[:3])

# Find the maximum and minimum in a list
nums = [43,65,2,4,6,43,2,34,23,45,7,87,43]

minNum = 100000
maxNum = 0

for num in nums:
    if (num < minNum):
        minNum = num
    if (num > maxNum):
        maxNum = num

print(maxNum, minNum)

# Find the sum of all the elements in the list
totalSum = 0
for num in nums:
    totalSum += num

print(totalSum)

# Check if the list is sorted or not (ascending)
# todo - tomorrow

# arr = [1,4,18,10,12]
# ans = True
# for i in range(0, len(arr) - 1):
#     if ( arr[i] > arr[i+1] ):
#         ans = False
#         break

# print(ans)
# Out:
# ['Apple', 'Cherry', 'Grapes', 'Watermelon', 'Avacado']
# ['Apple', 'Cherry', 'Grapes', 'Watermelon', 'Avacado', 'Lichi']
# ['Apple', 'Cherry', 'Guava', 'Grapes', 'Watermelon', 'Avacado', 'Lichi']
# ['Apple', 'Cherry', 'Guava']
# 87 2
# 404
# False

# %%
import copy

'''
DICTIONARY - collection of key-value pairs

PROPERTY
1. Unordered
2. Mutable (you can change)
3. Index by keys
4. Unique
'''
# laptop = {
#     "company": "apple",
#     "model": "m2",
#     "memory": 256,
# }
# print(laptop)

# ASSIGNMENT - create a dictionary of your phone - milestone 1
# phone = {
#     "company": "",
#     "ram": "",
#     "memory": "",   
# }

# ACCESS IN DICTIONARY
# print(laptop["model"])
# print(laptop["camera"])  # KeyError

# GET
# print( laptop.get("model") )
# print( laptop.get("camera") )
# print( laptop.get("camera", "4 mega pixel") )

# ITERATION ON DICTIONARY
# employee = {
#     "name": "Omraj",
#     "company": "ABC",
#     "area": "Green Glen",
#     "city": "Bangalore",
#     "state": "Karnataka",
#     "age": "10",
#     "pin": "560103",
#     "phone": "7503047413",
#     "email": "omraj7413@gmail.com"
# }

# for k in employee:
#     print(k, " : ", employee[k][:2])

# NESTED DICTIONARY
# employee1 = {
#     "name": "Omraj",
#     "phone": "7503047413",
#     "email": "omraj7413@gmail.com",
#     "company": "ABC",
#     "address": {
#         "area": "Green Glen",
#         "city": "Bangalore",
#         "state": "Karnataka",
#         "age": "10",
#         "pin": "560103",
#     }
# }

# ACCESS IN NESTED DICTIONARIES
# print( employee1["address"]["city"] )

# SHALLOW COPY
# employee2 = employee1
# employee1["name"] = "Om"
# employee2["name"] = "Shyam"
# print( employee1["name"] )

# DEEP COPY
# employee2 = copy.deepcopy(employee1)
# employee1["name"] = "Om"
# employee2["name"] = "Shyam"
# print( employee1["name"] )
# print( employee2["name"] )

# KEYS()
# print(employee2.keys())

# VALUES()
# print(employee2.values())

# ITEMS
# for ke, va in employee.items():
#     print(ke, va)

# UPDATE
# car = {
#     "engine": 1200,
#     "color": "black"
# }
# print(car)
# car.update({"mileage": 20, "model": "kia"})
# print(car)
# car.update({"color": "red", "model": "mahindra"})
# print(car)

# POP
# car = {
#     "engine": 1200,
#     "color": "black"
# }
# print(car)
# engine = car.pop("engine")
# print(engine)
# print(car)
# car.pop("something")  # KeyError

# CLEAR
# car = {
#     "engine": 1200,
#     "color": "black"
# }
# print(car)
# car.clear()
# print(car)

# COPY - shallow copy
# car2 = car.copy

# EMPLOYEE FILTER - (salary < 7500) - expected result dictionary {"Rajesh": 4500, "Ramesh": 7400}
employee = {
    "Ramu": 10000,
    "Shyamu": 7500,
    "Rajesh": 4500,
    "Nitin": 2900,
    "Ramesh": 7400
}

# result = {}

# for k, v in employee.items():
#     if (v < 7500):
#         result[k] = v

# print(result)

print(employee.values())
# Out:
# dict_values([10000, 7500, 4500, 2900, 7400])

# %%
'''
FUNCTIONS
'''

'''
REPEATING THE CODE
- Code duplicate
- Hard maintain
- Low reusability
'''
# a = 5
# b = 10 
# print(a+b)  # task

# x = 7
# y = 3
# print(x+y)

# p = 5
# q = 7
# print(p+q)

# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")

'''
BENEFITS OF FUNCTIONS/METHOD - workers
- ORGANISE CODE
- REUSABLE
- READABILITY

DRY prinple - Don't repeat yourself

create
use/call

Restaurant 
- Guard - Greet()
- Receptionist - check for booking, align available table
- Waiter - take order, serve order
- Cleaner - clean the table and nearby
- Chef - cook
- Manager - manage
'''

# def greet():
#     print("Hello sir/madam, Welcome to learnbay. Keep learing")

# greet()

# def reception(members):
#     if members <= 2:
#         print("provide a couple table")
#     elif members <= 4:
#         print("provide a family table")
#     elif members <= 10:
#         print("provide a party table")
#     else:
#         print("provide party hall")

# reception(2)
# reception(5)
# reception(1)
# reception(20)
# reception(3)

# def waiter(requirement):
#     if requirement == "water":
#         return "A bisleri water bottle"
#     if requirement == "menu":
#         return "Starts, Main course and Drinks Menu"
#     if requirement == "tissue":
#         return "Warm water with lime"
#     else :
#         return "Sorry sir/madam"

# response = waiter("tissue")
# print(response)
# print( waiter("Cold drink") )

# ARGUMENT - values we pass inside a function - in waiter function the argument is "requirement"

# DEFAULT ARGUMENTS
# def greet(name):
#     print("Hi " + name + " sir/madam, welcome to our restaurant. We believe you will love our hospitality.")

# greet("Omraj")
# greet("Anupam")
# greet()  # error - greet() missing 1 required positional argument: 'name'

# Guest is a default argument
# def greet(name = "Guest"):
#     print("Hi " + name + " sir/madam, welcome to our restaurant. We believe you will love our hospitality.")

# greet()
# greet("Shyam")
# greet()

# MULTIPLE ARGUMENT
# def addNumber(a, b):
#     print(a+b)

# addNumber(2,5)
# addNumber(6,3)
# addNumber(2,2)

# ARGUMENT ORDER
# def addNumber(a, b):
#     print(a)
#     print(b)
#     # print(a+b)

# addNumber(b=5, a=2)  # not recommentded

# VARIABLE LENGTH ARGUMENTS
# def addNumbers(*nums):
#     currentSum = 0
#     for num in nums:
#         currentSum += num
#     print(currentSum)

# addNumbers(1,2,3,4,5)

# ASSIGNMENT - PRACTICE THESE EXAMPLES
# Out:
# 15
# 3
# 0

# %%
'''
class 09 - MODULES
'''
# Out:
# Hello world!
# Hello world!

# %%
'''
class 10 - MORE INTO FUNCTIONS
'''
# def greet():
#     print("Hello and welcome to our party")

# greet()
# greet1 = greet
# wow = greet1
# greet1()
# wow()

# def square(x):
#     return x * x

# LABDA / ANONYMOUS
# functions with no name
# 1. SORT
# 2. SINGLE LINE FUNCTIONS
# 3. concise and redable

# square1 = lambda x : x * x
# print(square1(5))

# I am only using this code in map function, does that sense to you?
# def applyGst(price):
#     return price * 1.18

# MAP()
# prices = [100, 200, 300, 500]
# print( list( map( lambda price: price * 1.18 , prices ) ) )
# print(prices)

# FILTER()
# marks = [31, 57, 45, 29, 88]
# passed_marks = list(filter( lambda m: m >= 40 , marks ))
# print(passed_marks)

# salaries - filter salaries where salary is > 1000
# salaries = [180, 1200, 450, 1400, 2200]
# print ( list(filter(lambda s: s > 1000, salaries)) )
# print(salaries)

# REDUCE() - reduces list
# prices = [100, 250, 75]
# # bad code
# totalSum = 0
# for price in prices:
#     totalSum += price
# print(totalSum)

# from functools import reduce

# def reduceHelper(accumulator, currentVal):
#     return accumulator + currentVal

# prices = [2, 3, 4, 5]
# totalSum = reduce( reduceHelper , prices )
# print(totalSum)

# next button - ITERATOR - pointer
# my_list = [ 1, 2, 3 ]
# iterator = iter(my_list)
# print(next(iterator))
# print('hi')
# print(next(iterator))
# print(next(iterator))
# print(next(iterator))

# party_parking_folks = ["Raman", "Rony", "Dheeraj"]

salary=[700,1200,450,1400,2200]
salary_accept=list(filter(lambda salary:salary>=1000,salary))
print(salary_accept)
# Out:
# [1200, 1400, 2200]

# %%
'''
class 11 - FILE MANAGEMENT / HANDLING
- read
- update

Benifits
- Data permanent
- Share data between programs

Types of fiels
1. Text files - (.txt, .csv, .log, .html, .css, .py, .js etc.......)
2. Binary files - (audio, video, pdf, exe, - .jpg, .pdf, .exe, .mp3 etc.........)

Basic file operation
1. Open a file - open()
2. Read from file - 
3. Write from file - 
4. Close a file - close()

File Modes
r - read (default)
w - write
a - append (add to end of file)
b - binary (rb, wb)
x - create (fails if file exists)
+ - read and write 

LOG FILES - 100GB
extract - logs related to payment - 
create a new file - put only payment logs into it - 3 GB  - 100 Years -> 1 mins

file scrape data
- csv data -> excel data
'''

# f = open("sample.txt", "r")
# print(f.read())    # read entire file content
# print(f.readline())  # read first line
# print(f.readlines())  # read all lines into a list
# f.close()

# f = open("omraj/myfile.txt", "w")
# f.write("Hi Everyone to My File ~ Omraj Sharma")
# f.close()

# meeting attendance - append - (add at the last)
# while (True):
#     attendee = input("Enter the attendee's name")
# attendee = input("Enter the attendee's name")
# f = open("meeting-attendance.txt", "a")
# f.write(attendee + " ")
# f.close()

# tell() - return the current position of pointer in file
# f = open("meeting-attendance.txt", "r")
# print(f.read(8))
# print(f.tell())
# print(f.read(10))
# print(f.tell())
# f.close()

# total file size - 100000000000000000000000
# every minute - where my pointer 

# seek() - file pointer to a specific position
f = open("meeting-attendance.txt", "r")
print(f.read(8))
f.seek(10)  # move pointer to a paticular pointer
print(f.tell())
print(f.read(10))
print(f.tell())
f.close()

# f = open("meeting-attendance.txt", "w")
# f.write("")
# f.close()
# Out:
# Ankit
# Y
# 10
# esh
# Durga
# 20

# %%
'''
class 12 - EXCEPTION HANDLING
is the process of responding to the occrrence of exception (error)

Without exception handling 
- Your program crashes when an error occur
- User experience become poor

Types of errors
- Syntax error - if x > 5 print(x)
- Name error - print(num) when num is undefined
- Type error - 5 + "hello+
- Value error - int("abc")
- Index error - arr = [1,2] arr[5]
- Key error - d = {} d["x"]
- ZeroDivisionError - 5/0
- FileNotFoundError - open("nofile.txt")
'''

# BASIC STRUCTURE 
# try:
#     # Code that may cause an exception
# except ExceptionType:
#     # Code to run if there is an exception
# else:
#     # code to run if no exception occurs
# finally: 
#     # Code that always runs

# EXAMPLE 1
# try: 
#     num = int(input("Enter a number : "))
#     result = 10 / num
# except ZeroDivisionError:
#     print("You cannot divide by zero")
# else:
#     print("Division successful : ", result)
# finally: 
#     print("This always runs, no matter what")

# EXAMPLE 2
# try:
#     f = open("meeting-attendance.txt", "r")
#     print(f.read(5))
# except FileNotFoundError:
#     print("File doesn't exists")
# else:
#     print("File content loaded successfully")
# finally:
#     f.close()

# EXAMPLE 3
# try:
#     num = int(input("Enter a number: "))
#     result = 10 / num
#     f = open("omraj.txt", "r")
#     f.close()
# except ValueError:
#     print("Invalid input! Please enter a valid number")
# except ZeroDivisionError:
#     print("Cannot divide by zero")
# except FileNotFoundError:
#     print("File not found! Please check")
# except Exception as e:  # Generic error - should be added at last
#     print("Error occurred")

# USER DEFINED ERRORS
# class AgeTooSmallError(Exception):
#     pass
# try:
#     age = int(input("Enter your age: "))
#     if age < 18:
#         raise AgeTooSmallError
#     else:
#         print("You are eligible")
# except AgeTooSmallError:
#     print("Error: Age is too small. Must be at least 18.")

# REGULAR EXPRESSIONS - regex
# website - somedomain . something
# email - somename @ websitename . highLevelDomain
# email - omraj@gmail.com
# Indian phone number - 1234567890 - 10 numbers

import re

# MATCH - match at beginning
# result = re.match(r'Hello', 'Hello world')
# print(result)

# SEARCH - search anywhere
# result = re.search(r'world', "Hello world world")
# print(result)

# FIND ALL MATCHES
# result = re.findall(r'world', "Hello world world")
# print(result)

# text = "I have 2 apples and 3 bananas"
# result = re.findall(r'\d', text)
# print(result)

# text = "call me at 1234567890 or 0987654321 or 12345"
# result = re.findall(r'\d{10}', text)
# print(result)

# text = "1234567890"
# result = re.match(r'^\d{10}$', text)
# print(result)

email = "abc@gmail.com"
if re.match(r'^[\w\.-]+@[\w\.-]+\.\w+$', email):
    print("Valid email address")
else:
    print("Invalid email")
# Out:
# Valid email address

# %%
'''
ASSIGNMENT CLASS - 1
'''

# a = True
# b = True
# print(type(a))
# print(id(a))
# print(id(b))

# a = 100
# b = 100

# print(id(a))
# print(id(b))


# a = 10000
# b = 10000

# print(id(a))
# print(id(b))

a = True  # 1
b = False # 0
# print(a + b)
# print(a - b)
# print(a * b)
# # print(a / b)
# print(b / a)
# print(b % a)
# print(b ** a)
# print(b ** b)

# b = True
# print(a == b)
# print(a is b)
# print(type(a is b))

# a = 10.2
# b = 10.2
# print(type(a))
# print(id(a))
# print(id(b))
# print(a == b)
# print(a is b)

# print(10.20 and 20.30)
# print(0.0 and 20.30)

# print(-10 or 0)
# print(0 or -10)

# find highest element
# nums =[6,3,2,3,6,8,5,3,19,2,4,6,7,0]
# maxEl = -1
# for num in nums:
#     if num > maxEl:
#         maxEl = num
# print(maxEl)

# find second highest element
# nums =[6,3,2,3,6,8,5,3,19,2,4,6,7,0]
# maxEl = -1
# secondMaxEl = -1
# for num in nums:
#     if num > maxEl:
#         secondMaxEl = maxEl
#         maxEl = num
#     if num != maxEl and num > secondMaxEl:
#         secondMaxEl = num
# print(maxEl)
# print(secondMaxEl)

# max product of 3 elements
# nums = [-1, -2, 0, 9, 1, 4, 8, 6, 3, 2, -100, -10]
# nums.sort()
# print(nums)

# # 1. 3 max values
# # 2. 2 min value 1 max value

# l = len(nums)
# print(
#     max( 
#         nums[l-1] * nums[l-2] * nums[l-3], nums[0] * nums[1] * nums[l-1] 
#     )
# )

# factorial - 3! = 6, 4! = 24
# 4! -> 4 * 3 * 2 * 1
# take input number from user with exception handling and print factorial for that

# def factorial(n):
#     result = 1;
#     for i in range(1, n+1):
#         result *= i
#     return result

# try:
#     num = int(input("Entera non negative integer: "))
#     if num < 0:
#         raise ValueError("Negative number entered. Invalid input")
#     print(factorial(num))
# except ValueError as e:
#     print(e)
# Out:
# Entera non negative integer:  -10
# Negative number entered. Invalid input

# %%
'''
ASSIGNMENT 2 - conditionals, loops, etc
'''

# print lable of a number like
# 5 * 1 = 5
# 5 * 2 = 10 ... and soo on till * 10 

# num = 5
# for i in range(1, 11):
#     print(f"{num} * {i} = {num * i}")

# print even numbers from 1 - 100
# approach 1 - brute force
# for i in range(1, 101):
#     if i % 2 == 0:
#         print(i)

# approach 2 - optimised - 100/2 = 50 = n/2
# for i in range(2, 101, 2):
#     print(i)


# print sum from 1 - n (take n as input)
# n = int(input("Enter a number: "))
# total = 0
# for i in range(1, n+1):
#     total += i
# print(total)


# how to find the digits of a number
# n = int(input("Enter a number: "))
# while(n > 0):
#     lastNumber = n % 10
#     print(lastNumber)
#     n //= 10


# reverse a number 
# ex input = 1234, output = 4321
# n = int(input("Enter a number: "))
# rev = 0
# while(n > 0):
#     lastNumber = n % 10
#     rev = rev * 10 + lastNumber
#     n //= 10
# print(rev)


# sum of all digits of a number
# ex input = 1234, output = 1+2+3+4 = 10 answer





















# print this pattern
# *
# **
# ***
# ****
# *****
# rows = int(input("Enter total rows: "))
# for i in range(1, rows + 1):
#     for j in range(1, i + 1):
#         print("*", end="")
#     print()

# *****
# ****
# ***
# **
# *
# rows = int(input("Enter total rows: "))
# for i in range(1, rows + 1):
#     for j in range(1, rows - i + 2):
#         print("*", end="")
#     print()


# assignment - https://www.geeksforgeeks.org/java-pattern-programs/
# 1
# 12
# 123
# 1234e
# 12345

# SQUARE HOLLOW PATTERN
# n = int(input("Enter total rows: "))
# for i in range(0, n):
#     for j in range(0, n):
#         if (i == 0 or i == n-1 or j == 0 or j == n-1):
#             print("*", end="")
#         else: 
#             print(" ", end="")
#     print()

# RHOMBUS PATTERN
n = int(input("Enter total rows: "))
for i in range(0, n):
    for k in range(0, i):
        print(" ", end="")
    for j in range(0, n):
        print("*", end="")
    print()
# Out:
# Enter total rows:  5
# *****
#  *****
#   *****
#    *****
#     *****

# %%
'''
Banking system simulation
1. Create Account
2. Deposite
3. Withdraw
4. Check Balance
5. Exit
'''

bank_data = {}
account_count = 1001

def create_account(name):
    global account_count
    account_number = account_count
    bank_data[account_number] = {"name": name, "balance": 0.0}
    account_count += 1
    print(f"🟢 Account created successfully! Account Number: {account_number}")

def deposit(account_number, amount):
    if account_number in bank_data:
        bank_data[account_number]["balance"] += amount
        print(f"🟢 Deposited ${amount}. New Balance : {bank_data[account_number]["balance"]}")
    else:
        print("🛑 Invalid account number.")

def withdraw(account_number, amount):
    if account_number in bank_data:
        if bank_data[account_number]["balance"] >= amount:
            bank_data[account_number]["balance"] -= amount
            print(f"🟢 Withdrawn ${amount}. New Balance : {bank_data[account_number]["balance"]}")
        else:
            print("🛑 Insufficient balance.")
    else:
        print("🛑 Invalid account number.")

def check_balance(account_number):
    if account_number in bank_data:
        print(f"Account Holder: {bank_data[account_number]["name"]}")
        print(f"Current Balance: {bank_data[account_number]["balance"]}")
    else:
        print("🛑 Invalid account number.")

while True:
    print("\nOptions:")
    print("1. Create Account")
    print("2. Deposit")
    print("3. Withdraw")
    print("4. Check Balance")
    print("5. Exit")
    choice = input("Enter your choice (1-5): ")

    if choice == '1':
        name = input("Enter your name: ")
        create_account(name)
    elif choice == '2':
        acc = int(input("Enter account number: "))
        amt = float(input("Enter amount to deposite"))
        deposit(acc, amt)
    elif choice == '3':
        acc = int(input("Enter account number: "))
        amt = float(input("Enter amount to withdraw"))
        withdraw(acc, amt)
    elif choice == '5':
        print("Thank you for using Python Bank. GoodBye")
        break
    else:
        print("🛑 Invalid choice. Please try again")
# Out:
# Options:
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Exit
# Enter your choice (1-5):  1
# Enter your name:  om
# 🟢 Account created successfully! Account Number: 1001
#
# Options:
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Exit
# Enter your choice (1-5):  2
# Enter account number:  1001
# Enter amount to deposite 100
# 🟢 Deposited $100.0. New Balance : 100.0
#
# Options:
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Exit
# Enter your choice (1-5):  3
# Enter account number:  1001
# Enter amount to withdraw 10
# 🟢 Withdrawn $10.0. New Balance : 90.0
#
# Options:
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Exit
# Enter your choice (1-5):  3
# Enter account number:  1001
# Enter amount to withdraw 1000
# 🛑 Insufficient balance.
#
# Options:
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Exit
# Enter your choice (1-5):  4
# 🛑 Invalid choice. Please try again
#
# Options:
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[316], line 51
#      49 print("4. Check Balance")
#      50 print("5. Exit")
# ---> 51 choice = input("Enter your choice (1-5): ")
#      53 if choice == '1':
#      54     name = input("Enter your name: ")
#
# File /opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
