# %% [markdown]
# ### data file is present here : https://drive.google.com/file/d/1Knl92dpOpWcVFVXCytADeC9VguLpDDMc/view?usp=sharing

# %% [markdown]
# # Case Study 2

# %% [markdown]
# Airbnb

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('airbnb.csv')

# %%
df.head(2)
# Out:
#       id                         listing_url  \
# 0  11156  https://www.airbnb.com/rooms/11156
# 1  12351  https://www.airbnb.com/rooms/12351
#
#                                 name  host_id host_name host_since  \
# 0               An Oasis in the City    40855   Colleen   23/09/09
# 1  Sydney City & Harbour at the door    17061    Stuart   14/05/09
#
#   host_is_superhost host_identity_verified                       street  \
# 0                 t                      f  Potts Point, NSW, Australia
# 1                 f                      t      Pyrmont, NSW, Australia
#
#           city  ... monthly_price security_deposit cleaning_fee  \
# 0  Potts Point  ...           NaN              NaN          NaN
# 1      Pyrmont  ...           NaN           $0.00       $55.00
#
#    guests_included  extra_people has_availability number_of_reviews  \
# 0                1        $0.00                 1               177
# 1                2      $395.00                 1               468
#
#    review_scores_rating  instant_bookable          cancellation_policy
# 0                  92.0                 f                     moderate
# 1                  95.0                 f  strict_14_with_grace_period
#
# [2 rows x 36 columns]

# %%
df.shape
# Out:
# (27076, 36)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy'],
#       dtype='object')

# %%
df['property_type'].head()
# Out:
# 0    Apartment
# 1    Townhouse
# 2        House
# 3    Apartment
# 4    Apartment
# Name: property_type, dtype: object

# %%
df['room_type'].head()
# Out:
# 0       Private room
# 1       Private room
# 2    Entire home/apt
# 3       Private room
# 4        Shared room
# Name: room_type, dtype: object

# %%
df['accommodates'].head()
# Out:
# 0    1
# 1    2
# 2    6
# 3    2
# 4    1
# Name: accommodates, dtype: int64

# %%
# view multiple columns at once - column names : price, weekly_price, monthly_price - head 3

# %%
df[['price','weekly_price','monthly_price']].head(3)
# Out:
#       price weekly_price monthly_price
# 0   $65.00           NaN           NaN
# 1   $98.00      $800.00            NaN
# 2  $469.00    $3,000.00            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27076 entries, 0 to 27075
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      27076 non-null  int64
#  1   listing_url             27076 non-null  object
#  2   name                    27062 non-null  object
#  3   host_id                 27076 non-null  int64
#  4   host_name               27041 non-null  object
#  5   host_since              27041 non-null  object
#  6   host_is_superhost       27041 non-null  object
#  7   host_identity_verified  27041 non-null  object
#  8   street                  27076 non-null  object
#  9   city                    27043 non-null  object
#  10  state                   27067 non-null  object
#  11  country_code            27076 non-null  object
#  12  country                 27076 non-null  object
#  13  latitude                27076 non-null  float64
#  14  longitude               27076 non-null  float64
#  15  property_type           27076 non-null  object
#  16  room_type               27076 non-null  object
#  17  accommodates            27076 non-null  int64
#  18  bathrooms               27054 non-null  float64
#  19  bedrooms                27068 non-null  float64
#  20  beds                    27043 non-null  float64
#  21  bed_type                27076 non-null  object
#  22  amenities               27076 non-null  object
#  23  square_feet             256 non-null    float64
#  24  price                   27076 non-null  object
#  25  weekly_price            3921 non-null   object
#  26  monthly_price           2375 non-null   object
#  27  security_deposit        16725 non-null  object
#  28  cleaning_fee            19253 non-null  object
#  29  guests_included         27076 non-null  int64
#  30  extra_people            27076 non-null  object
#  31  has_availability        27076 non-null  int64
#  32  number_of_reviews       27076 non-null  int64
#  33  review_scores_rating    19517 non-null  float64
#  34  instant_bookable        27076 non-null  object
#  35  cancellation_policy     27076 non-null  object
# dtypes: float64(7), int64(6), object(23)
# memory usage: 7.4+ MB

# %%
df.head()
# Out:
#       id                         listing_url  \
# 0  11156  https://www.airbnb.com/rooms/11156
# 1  12351  https://www.airbnb.com/rooms/12351
# 2  14250  https://www.airbnb.com/rooms/14250
# 3  14935  https://www.airbnb.com/rooms/14935
# 4  14974  https://www.airbnb.com/rooms/14974
#
#                                      name  host_id host_name host_since  \
# 0                    An Oasis in the City    40855   Colleen   23/09/09
# 1       Sydney City & Harbour at the door    17061    Stuart   14/05/09
# 2                     Manly Harbour House    55948     Heidi   20/11/09
# 3  Eco-conscious Travellers: Private Room    58796     Kevin   30/11/09
# 4     Eco-conscious Traveller: Sofa Couch    58796     Kevin   30/11/09
#
#   host_is_superhost host_identity_verified                       street  \
# 0                 t                      f  Potts Point, NSW, Australia
# 1                 f                      t      Pyrmont, NSW, Australia
# 2                 f                      t    Balgowlah, NSW, Australia
# 3                 f                      t      Redfern, NSW, Australia
# 4                 f                      t      Redfern, NSW, Australia
#
#           city  ... monthly_price security_deposit cleaning_fee  \
# 0  Potts Point  ...           NaN              NaN          NaN
# 1      Pyrmont  ...           NaN           $0.00       $55.00
# 2    Balgowlah  ...           NaN         $900.00      $100.00
# 3      Redfern  ...           NaN              NaN          NaN
# 4      Redfern  ...           NaN              NaN          NaN
#
#    guests_included  extra_people has_availability number_of_reviews  \
# 0                1        $0.00                 1               177
# 1                2      $395.00                 1               468
# 2                6       $40.00                 1                 1
# 3                1       $40.00                 1               172
# 4                1        $0.00                 1               147
#
#    review_scores_rating  instant_bookable          cancellation_policy
# 0                  92.0                 f                     moderate
# 1                  95.0                 f  strict_14_with_grace_period
# 2                 100.0                 f  strict_14_with_grace_period
# 3                  89.0                 f                     moderate
# 4                  90.0                 f                     moderate
#
# [5 rows x 36 columns]

# %%
df.sample(3)
# Out:
#              id                            listing_url  \
# 2979    4663412   https://www.airbnb.com/rooms/4663412
# 20201  20058952  https://www.airbnb.com/rooms/20058952
# 3656    5232870   https://www.airbnb.com/rooms/5232870
#
#                                                     name    host_id  \
# 2979            COOGEE Smithfield Avenue (Villa)-L'Abode    7409213
# 20201  Oceanview House A Luxury Home Close to Bondi B...  142518386
# 3656                     Single room to rent for 10 days   27082604
#
#                               host_name host_since host_is_superhost  \
# 2979   L'Abode Accommodation Specialist   10/07/13                 f
# 20201                           Bridget   25/07/17                 t
# 3656                              Peter    2/02/15                 f
#
#       host_identity_verified                         street           city  \
# 2979                       t         Coogee, NSW, Australia         Coogee
# 20201                      f  Dover Heights, NSW, Australia  Dover Heights
# 3656                       f    North Bondi, NSW, Australia    North Bondi
#
#        ... monthly_price security_deposit cleaning_fee  guests_included  \
# 2979   ...           NaN         $500.00      $370.00                 1
# 20201  ...           NaN       $1,000.00      $365.00                 1
# 3656   ...           NaN              NaN          NaN                1
#
#        extra_people has_availability number_of_reviews  review_scores_rating  \
# 2979         $0.00                 1                21                  87.0
# 20201        $0.00                 1                19                  96.0
# 3656         $0.00                 1                 1                 100.0
#
#        instant_bookable          cancellation_policy
# 2979                  t  strict_14_with_grace_period
# 20201                 f  strict_14_with_grace_period
# 3656                  f                     flexible
#
# [3 rows x 36 columns]

# %%
df.sample()
# Out:
#              id                            listing_url  \
# 22755  21489546  https://www.airbnb.com/rooms/21489546
#
#                                                 name    host_id host_name  \
# 22755  Executive studio just next to Darling Harbour  124342964    Coffee
#
#       host_since host_is_superhost host_identity_verified  \
# 22755    5/04/17                 f                      f
#
#                        street    city  ... monthly_price security_deposit  \
# 22755  Sydney, NSW, Australia  Sydney  ...           NaN         $450.00
#
#       cleaning_fee  guests_included  extra_people has_availability  \
# 22755      $80.00                 2       $25.00                 1
#
#       number_of_reviews  review_scores_rating  instant_bookable  \
# 22755                49                  96.0                 t
#
#                cancellation_policy
# 22755  strict_14_with_grace_period
#
# [1 rows x 36 columns]

# %%
df['amenities']
# Out:
# 0        {TV,Kitchen,Elevator,"Buzzer/wireless intercom...
# 1        {TV,Internet,Wifi,"Air conditioning","Paid par...
# 2        {TV,Wifi,"Air conditioning",Kitchen,"Pets live...
# 3        {Internet,Wifi,"Wheelchair accessible",Pool,Ki...
# 4        {Internet,Wifi,Pool,Kitchen,Gym,Elevator,"Buzz...
#                                ...
# 27071    {Wifi,Kitchen,"Family/kid friendly",Washer,"Sm...
# 27072    {TV,"Cable TV",Wifi,Pool,Kitchen,"Free street ...
# 27073    {TV,Wifi,"Indoor fireplace",Heating,Washer,"Sm...
# 27074    {TV,Internet,Wifi,"Air conditioning",Pool,Kitc...
# 27075    {TV,Wifi,Kitchen,Heating,"Family/kid friendly"...
# Name: amenities, Length: 27076, dtype: object

# %%
am1 = df['amenities'].iloc[0]
am1
# Out:
# '{TV,Kitchen,Elevator,"Buzzer/wireless intercom",Heating,Washer,"Smoke detector","Fire extinguisher",Essentials,Hangers,"Hair dryer",Iron,"Bed linens","Extra pillows and blankets",Microwave,Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Stove,"Single level home","Patio or balcony","Garden or backyard"}'

# %%
am1.split(',')
# Out:
# ['{TV',
#  'Kitchen',
#  'Elevator',
#  '"Buzzer/wireless intercom"',
#  'Heating',
#  'Washer',
#  '"Smoke detector"',
#  '"Fire extinguisher"',
#  'Essentials',
#  'Hangers',
#  '"Hair dryer"',
#  'Iron',
#  '"Bed linens"',
#  '"Extra pillows and blankets"',
#  'Microwave',
#  'Refrigerator',
#  'Dishwasher',
#  '"Dishes and silverware"',
#  '"Cooking basics"',
#  'Stove',
#  '"Single level home"',
#  '"Patio or balcony"',
#  '"Garden or backyard"}']

# %%
len(am1.split(','))
# Out:
# 23

# %%
def get_amenities_count(amenities):
    return len(amenities.split(','))

# %%
df['amenities'].apply(get_amenities_count)
# Out:
# 0        23
# 1        29
# 2        20
# 3        17
# 4         9
#          ..
# 27071     9
# 27072    20
# 27073    25
# 27074    15
# 27075    31
# Name: amenities, Length: 27076, dtype: int64

# %%
# create a new column for amenities count
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy'],
#       dtype='object')

# %%
df['amenities_count'] = df['amenities'].apply(get_amenities_count)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy',
#        'amenities_count'],
#       dtype='object')

# %%
df['extra_people']
# Out:
# 0          $0.00
# 1        $395.00
# 2         $40.00
# 3         $40.00
# 4          $0.00
#            ...
# 27071      $0.00
# 27072     $50.00
# 27073     $25.00
# 27074    $100.00
# 27075      $0.00
# Name: extra_people, Length: 27076, dtype: object

# %%
cols_to_delete = ['listing_url', 'name', 'host_id', 'host_name', 'street', 'city', 'state',
                 'country_code', 'amenities', 'instant_bookable', 'cancellation_policy']
df.drop(cols_to_delete, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'host_since', 'host_is_superhost', 'host_identity_verified',
#        'country', 'latitude', 'longitude', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'square_feet', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'has_availability', 'number_of_reviews', 'review_scores_rating',
#        'amenities_count'],
#       dtype='object')

# %% [markdown]
# ### Look for duplicate rows

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27071     True
# 27072     True
# 27073     True
# 27074     True
# 27075     True
# Length: 27076, dtype: bool

# %%
df[df.duplicated()]
# Out:
#              id host_since host_is_superhost host_identity_verified  \
# 27070  22151172   24/11/17                 f                      f
# 27071  16444390   13/04/16                 f                      f
# 27072  14829119   26/04/10                 f                      t
# 27073  15918138    9/07/16                 f                      t
# 27074   8977894   19/10/15                 f                      t
# 27075  17642461    7/01/14                 f                      f
#
#          country   latitude   longitude      property_type        room_type  \
# 27070  Australia -33.918303  151.220225              House     Private room
# 27071  Australia -33.917357  151.257003          Apartment     Private room
# 27072  Australia -33.903898  151.262101              House  Entire home/apt
# 27073  Australia -33.884917  151.213145  Bed and breakfast     Private room
# 27074  Australia -33.816418  151.245770              House  Entire home/apt
# 27075  Australia -33.884099  151.227863              House  Entire home/apt
#
#        accommodates  ...  weekly_price  monthly_price  security_deposit  \
# 27070             1  ...           NaN            NaN               NaN
# 27071             2  ...           NaN            NaN               NaN
# 27072             7  ...           NaN            NaN        $3,000.00
# 27073             2  ...           NaN            NaN               NaN
# 27074            10  ...    $8,000.00             NaN        $2,000.00
# 27075             5  ...           NaN            NaN            $0.00
#
#       cleaning_fee  guests_included extra_people has_availability  \
# 27070          NaN                1       $0.00                 1
# 27071          NaN                1       $0.00                 1
# 27072     $425.00                 6      $50.00                 1
# 27073          NaN                1      $25.00                 1
# 27074     $390.00                 8     $100.00                 1
# 27075     $120.00                 5       $0.00                 1
#
#       number_of_reviews review_scores_rating amenities_count
# 27070                 1                 60.0              17
# 27071                15                 97.0               9
# 27072                 0                  NaN              20
# 27073                 7                100.0              25
# 27074                 7                 97.0              15
# 27075                 8                 90.0              31
#
# [6 rows x 26 columns]

# %%
df[df.duplicated(keep=False)] # original + duplicate instances
# Out:
#              id host_since host_is_superhost host_identity_verified  \
# 6628    8977894   19/10/15                 f                      t
# 12829  14829119   26/04/10                 f                      t
# 14305  15918138    9/07/16                 f                      t
# 15788  16444390   13/04/16                 f                      f
# 17239  17642461    7/01/14                 f                      f
# 25249  22151172   24/11/17                 f                      f
# 27070  22151172   24/11/17                 f                      f
# 27071  16444390   13/04/16                 f                      f
# 27072  14829119   26/04/10                 f                      t
# 27073  15918138    9/07/16                 f                      t
# 27074   8977894   19/10/15                 f                      t
# 27075  17642461    7/01/14                 f                      f
#
#          country   latitude   longitude      property_type        room_type  \
# 6628   Australia -33.816418  151.245770              House  Entire home/apt
# 12829  Australia -33.903898  151.262101              House  Entire home/apt
# 14305  Australia -33.884917  151.213145  Bed and breakfast     Private room
# 15788  Australia -33.917357  151.257003          Apartment     Private room
# 17239  Australia -33.884099  151.227863              House  Entire home/apt
# 25249  Australia -33.918303  151.220225              House     Private room
# 27070  Australia -33.918303  151.220225              House     Private room
# 27071  Australia -33.917357  151.257003          Apartment     Private room
# 27072  Australia -33.903898  151.262101              House  Entire home/apt
# 27073  Australia -33.884917  151.213145  Bed and breakfast     Private room
# 27074  Australia -33.816418  151.245770              House  Entire home/apt
# 27075  Australia -33.884099  151.227863              House  Entire home/apt
#
#        accommodates  ...  weekly_price  monthly_price  security_deposit  \
# 6628             10  ...    $8,000.00             NaN        $2,000.00
# 12829             7  ...           NaN            NaN        $3,000.00
# 14305             2  ...           NaN            NaN               NaN
# 15788             2  ...           NaN            NaN               NaN
# 17239             5  ...           NaN            NaN            $0.00
# 25249             1  ...           NaN            NaN               NaN
# 27070             1  ...           NaN            NaN               NaN
# 27071             2  ...           NaN            NaN               NaN
# 27072             7  ...           NaN            NaN        $3,000.00
# 27073             2  ...           NaN            NaN               NaN
# 27074            10  ...    $8,000.00             NaN        $2,000.00
# 27075             5  ...           NaN            NaN            $0.00
#
#       cleaning_fee  guests_included extra_people has_availability  \
# 6628      $390.00                 8     $100.00                 1
# 12829     $425.00                 6      $50.00                 1
# 14305          NaN                1      $25.00                 1
# 15788          NaN                1       $0.00                 1
# 17239     $120.00                 5       $0.00                 1
# 25249          NaN                1       $0.00                 1
# 27070          NaN                1       $0.00                 1
# 27071          NaN                1       $0.00                 1
# 27072     $425.00                 6      $50.00                 1
# 27073          NaN                1      $25.00                 1
# 27074     $390.00                 8     $100.00                 1
# 27075     $120.00                 5       $0.00                 1
#
#       number_of_reviews review_scores_rating amenities_count
# 6628                  7                 97.0              15
# 12829                 0                  NaN              20
# 14305                 7                100.0              25
# 15788                15                 97.0               9
# 17239                 8                 90.0              31
# 25249                 1                 60.0              17
# 27070                 1                 60.0              17
# 27071                15                 97.0               9
# 27072                 0                  NaN              20
# 27073                 7                100.0              25
# 27074                 7                 97.0              15
# 27075                 8                 90.0              31
#
# [12 rows x 26 columns]

# %%
rows_to_delete = df[df.duplicated()].index

# %%
rows_to_delete
# Out:
# Index([27070, 27071, 27072, 27073, 27074, 27075], dtype='int64')

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#              id host_since host_is_superhost host_identity_verified  \
# 0         11156   23/09/09                 t                      f
# 1         12351   14/05/09                 f                      t
# 2         14250   20/11/09                 f                      t
# 3         14935   30/11/09                 f                      t
# 4         14974   30/11/09                 f                      t
# ...         ...        ...               ...                    ...
# 27065  22708135   16/02/17                 f                      t
# 27066  22708238   12/01/18                 f                      f
# 27067  22709306   11/01/18                 f                      f
# 27068  22709315   13/01/18                 f                      f
# 27069  22709659   13/12/14                 f                      f
#
#          country   latitude   longitude property_type        room_type  \
# 0      Australia -33.869168  151.226562     Apartment     Private room
# 1      Australia -33.865153  151.191896     Townhouse     Private room
# 2      Australia -33.800929  151.261722         House  Entire home/apt
# 3      Australia -33.890765  151.200450     Apartment     Private room
# 4      Australia -33.889667  151.200896     Apartment      Shared room
# ...          ...        ...         ...           ...              ...
# 27065  Australia -33.883947  151.194421         Other  Entire home/apt
# 27066  Australia -33.923985  151.064296         House     Private room
# 27067  Australia -33.873479  151.197017     Apartment  Entire home/apt
# 27068  Australia -33.890265  151.207475         House  Entire home/apt
# 27069  Australia -33.882840  151.219972          Loft  Entire home/apt
#
#        accommodates  ...  weekly_price  monthly_price  security_deposit  \
# 0                 1  ...           NaN            NaN               NaN
# 1                 2  ...      $800.00             NaN            $0.00
# 2                 6  ...    $3,000.00             NaN          $900.00
# 3                 2  ...           NaN            NaN               NaN
# 4                 1  ...           NaN            NaN               NaN
# ...             ...  ...           ...            ...               ...
# 27065             2  ...           NaN            NaN          $200.00
# 27066             2  ...           NaN            NaN               NaN
# 27067             6  ...           NaN            NaN          $300.00
# 27068            11  ...           NaN            NaN          $400.00
# 27069             2  ...           NaN            NaN               NaN
#
#       cleaning_fee  guests_included extra_people has_availability  \
# 0              NaN                1       $0.00                 1
# 1          $55.00                 2     $395.00                 1
# 2         $100.00                 6      $40.00                 1
# 3              NaN                1      $40.00                 1
# 4              NaN                1       $0.00                 1
# ...            ...              ...          ...              ...
# 27065       $0.00                 2      $30.00                 1
# 27066          NaN                1       $0.00                 1
# 27067      $80.00                 4      $20.00                 1
# 27068     $120.00                 4      $25.00                 1
# 27069      $50.00                 1       $0.00                 1
#
#       number_of_reviews review_scores_rating amenities_count
# 0                   177                 92.0              23
# 1                   468                 95.0              29
# 2                     1                100.0              20
# 3                   172                 89.0              17
# 4                   147                 90.0               9
# ...                 ...                  ...             ...
# 27065                17                 96.0              21
# 27066                 0                  NaN              18
# 27067                 8                 90.0              51
# 27068                28                 97.0              35
# 27069                32                 90.0              24
#
# [27070 rows x 26 columns]

# %%
# Summary

# %%
df.describe()
# Out:
#                  id      latitude     longitude  accommodates     bathrooms  \
# count  2.707000e+04  27070.000000  27070.000000  27070.000000  27048.000000
# mean   1.402672e+07    -33.862368    151.210667      3.383598      1.352337
# std    6.520952e+06      0.072260      0.079451      2.196864      0.664092
# min    1.115600e+04    -34.135212    150.644964      1.000000      0.000000
# 25%    9.083668e+06    -33.897603    151.184472      2.000000      1.000000
# 50%    1.544074e+07    -33.883064    151.223242      2.000000      1.000000
# 75%    2.015561e+07    -33.831850    151.264888      4.000000      1.500000
# max    2.270966e+07    -33.389728    151.339811     16.000000     10.000000
#
#            bedrooms          beds   square_feet  guests_included  \
# count  27062.000000  27037.000000    256.000000     27070.000000
# mean       1.614071      2.012169    421.453125         1.515146
# std        1.109725      1.526399   1573.511992         1.256044
# min        0.000000      0.000000      0.000000         1.000000
# 25%        1.000000      1.000000      0.000000         1.000000
# 50%        1.000000      1.000000      0.000000         1.000000
# 75%        2.000000      2.000000    282.500000         1.000000
# max       46.000000     29.000000  21528.000000        16.000000
#
#        has_availability  number_of_reviews  review_scores_rating  \
# count           27070.0       27070.000000          19512.000000
# mean                1.0          14.005689             93.412413
# std                 0.0          29.808917              9.354959
# min                 1.0           0.000000             20.000000
# 25%                 1.0           0.000000             90.000000
# 50%                 1.0           3.000000             96.000000
# 75%                 1.0          13.000000            100.000000
# max                 1.0         468.000000            100.000000
#
#        amenities_count
# count     27070.000000
# mean         20.343517
# std          10.908119
# min           1.000000
# 25%          13.000000
# 50%          17.000000
# 75%          25.000000
# max         101.000000

# %%
# Find the listings without a bathroom
df[df['bathrooms'] == 0]
# Out:
#              id host_since host_is_superhost host_identity_verified  \
# 1232    2064031   11/12/13                 f                      f
# 1373    2257635   13/01/14                 f                      t
# 1934    3334584   19/09/12                 f                      f
# 2307    4033572    8/07/14                 f                      t
# 2420    4184110   11/08/11                 t                      f
# ...         ...        ...               ...                    ...
# 24923  22069561   16/12/14                 f                      t
# 25600  22218527   18/04/17                 f                      t
# 25769  22265628   24/02/17                 f                      t
# 25993  22309457    4/11/15                 f                      f
# 26636  22485646   18/04/17                 f                      t
#
#          country   latitude   longitude property_type        room_type  \
# 1232   Australia -33.894637  151.270324     Apartment     Private room
# 1373   Australia -33.889880  151.186930         Other     Private room
# 1934   Australia -33.887708  151.274682     Apartment     Private room
# 2307   Australia -33.836565  151.216093     Apartment     Private room
# 2420   Australia -33.765936  151.184232         House     Private room
# ...          ...        ...         ...           ...              ...
# 24923  Australia -33.937308  151.145314         House     Private room
# 25600  Australia -33.917258  151.238008    Guesthouse     Private room
# 25769  Australia -33.827467  151.207367     Apartment  Entire home/apt
# 25993  Australia -33.851926  151.135485          Boat  Entire home/apt
# 26636  Australia -33.915403  151.239529    Guesthouse     Private room
#
#        accommodates  ...  weekly_price  monthly_price  security_deposit  \
# 1232              2  ...           NaN            NaN               NaN
# 1373              2  ...           NaN            NaN          $150.00
# 1934              2  ...           NaN            NaN               NaN
# 2307              1  ...      $800.00      $3,000.00                NaN
# 2420              2  ...           NaN            NaN            $0.00
# ...             ...  ...           ...            ...               ...
# 24923             2  ...           NaN            NaN               NaN
# 25600             2  ...           NaN            NaN        $1,500.00
# 25769             2  ...           NaN            NaN               NaN
# 25993             1  ...           NaN            NaN               NaN
# 26636             2  ...           NaN            NaN          $800.00
#
#       cleaning_fee  guests_included extra_people has_availability  \
# 1232           NaN                1       $0.00                 1
# 1373           NaN                1       $0.00                 1
# 1934           NaN                1       $0.00                 1
# 2307           NaN                1       $0.00                 1
# 2420       $10.00                 2      $20.00                 1
# ...            ...              ...          ...              ...
# 24923          NaN                1       $0.00                 1
# 25600      $20.00                 1      $35.00                 1
# 25769          NaN                1       $0.00                 1
# 25993          NaN                1       $0.00                 1
# 26636      $15.00                 1      $35.00                 1
#
#       number_of_reviews review_scores_rating amenities_count
# 1232                  0                  NaN              16
# 1373                  7                 89.0               6
# 1934                  0                  NaN              11
# 2307                  4                100.0              13
# 2420                 42                 96.0              29
# ...                 ...                  ...             ...
# 24923                 5                100.0              33
# 25600                 4                 93.0              33
# 25769                 0                  NaN              23
# 25993                 0                  NaN              13
# 26636                 1                100.0              19
#
# [74 rows x 26 columns]

# %%
df[df['bedrooms'] == 0]
# Out:
#              id host_since host_is_superhost host_identity_verified  \
# 16        63795    6/12/10                 f                      t
# 128      348891   14/08/10                 t                      t
# 147      387130   17/03/12                 t                      f
# 159      405432   27/03/12                 t                      t
# 170      421997    9/04/12                 f                      t
# ...         ...        ...               ...                    ...
# 27012  22679407   12/03/17                 f                      f
# 27020  22689848   28/09/14                 f                      f
# 27027  22691962   11/01/18                 f                      f
# 27058  22706892   17/12/10                 t                      t
# 27065  22708135   16/02/17                 f                      t
#
#          country   latitude   longitude property_type        room_type  \
# 16     Australia -33.626121  151.331511    Guesthouse  Entire home/apt
# 128    Australia -33.889585  151.274061     Apartment  Entire home/apt
# 147    Australia -33.920617  151.252932     Apartment  Entire home/apt
# 159    Australia -33.764294  151.258517   Guest suite  Entire home/apt
# 170    Australia -33.640853  151.320228     Apartment  Entire home/apt
# ...          ...        ...         ...           ...              ...
# 27012  Australia -33.881354  151.221382     Apartment  Entire home/apt
# 27020  Australia -33.879184  151.218873     Apartment  Entire home/apt
# 27027  Australia -33.876629  151.217844         House     Private room
# 27058  Australia -33.810739  151.160904         House  Entire home/apt
# 27065  Australia -33.883947  151.194421         Other  Entire home/apt
#
#        accommodates  ...  weekly_price  monthly_price  security_deposit  \
# 16                2  ...           NaN            NaN          $600.00
# 128               2  ...           NaN     $3,100.00           $750.00
# 147               2  ...           NaN            NaN            $0.00
# 159               2  ...           NaN            NaN            $0.00
# 170               2  ...           NaN            NaN               NaN
# ...             ...  ...           ...            ...               ...
# 27012             2  ...           NaN            NaN            $0.00
# 27020             2  ...           NaN            NaN          $450.00
# 27027             2  ...           NaN            NaN               NaN
# 27058             4  ...           NaN            NaN            $0.00
# 27065             2  ...           NaN            NaN          $200.00
#
#       cleaning_fee  guests_included extra_people has_availability  \
# 16         $45.00                 1       $0.00                 1
# 128       $120.00                 1       $0.00                 1
# 147        $20.00                 1       $0.00                 1
# 159        $20.00                 1       $0.00                 1
# 170        $50.00                 1       $0.00                 1
# ...            ...              ...          ...              ...
# 27012      $30.00                 1       $0.00                 1
# 27020     $145.00                 1       $0.00                 1
# 27027          NaN                1       $0.00                 1
# 27058       $0.00                 2      $15.00                 1
# 27065       $0.00                 2      $30.00                 1
#
#       number_of_reviews review_scores_rating amenities_count
# 16                   46                 96.0              42
# 128                  20                 93.0              34
# 147                 176                 95.0              20
# 159                 255                 95.0              39
# 170                  87                 98.0              20
# ...                 ...                  ...             ...
# 27012                 2                100.0              21
# 27020                 7                 90.0              28
# 27027                 1                  NaN              14
# 27058                24                 99.0              22
# 27065                17                 96.0              21
#
# [1383 rows x 26 columns]

# %%
df[df['beds'] == 0]
# Out:
#              id host_since host_is_superhost host_identity_verified  \
# 91       264925    9/11/11                 f                      t
# 149      389876   17/03/12                 t                      t
# 169      420647    8/04/12                 t                      t
# 170      421997    9/04/12                 f                      t
# 171      424931   10/04/12                 f                      f
# ...         ...        ...               ...                    ...
# 25438  22194078   24/10/16                 f                      f
# 25534  22210446   11/12/17                 f                      f
# 26377  22394860   22/12/16                 f                      f
# 26649  22487326   10/10/16                 f                      f
# 26655  22488321   27/01/12                 t                      t
#
#          country   latitude   longitude property_type        room_type  \
# 91     Australia -33.886952  151.278457     Apartment  Entire home/apt
# 149    Australia -33.889261  151.201722     Apartment  Entire home/apt
# 169    Australia -33.892851  151.189886         House  Entire home/apt
# 170    Australia -33.640853  151.320228     Apartment  Entire home/apt
# 171    Australia -33.892972  151.204709         House     Private room
# ...          ...        ...         ...           ...              ...
# 25438  Australia -33.871863  151.172801         House  Entire home/apt
# 25534  Australia -33.798500  151.281200     Apartment  Entire home/apt
# 26377  Australia -33.874547  151.204855     Apartment  Entire home/apt
# 26649  Australia -33.896097  151.178977     Apartment  Entire home/apt
# 26655  Australia -33.890415  151.207799   Condominium  Entire home/apt
#
#        accommodates  ...  weekly_price  monthly_price  security_deposit  \
# 91                7  ...           NaN            NaN        $1,500.00
# 149               4  ...           NaN            NaN          $300.00
# 169               3  ...    $1,045.00      $3,990.00                NaN
# 170               2  ...           NaN            NaN               NaN
# 171               2  ...           NaN            NaN               NaN
# ...             ...  ...           ...            ...               ...
# 25438             5  ...           NaN            NaN          $500.00
# 25534             2  ...           NaN            NaN          $250.00
# 26377             4  ...           NaN            NaN            $0.00
# 26649             2  ...           NaN            NaN          $250.00
# 26655             4  ...           NaN            NaN          $500.00
#
#       cleaning_fee  guests_included extra_people has_availability  \
# 91        $165.00                 7      $50.00                 1
# 149        $87.00                 2      $50.00                 1
# 169            NaN                2      $48.00                 1
# 170        $50.00                 1       $0.00                 1
# 171        $35.00                 1       $0.00                 1
# ...            ...              ...          ...              ...
# 25438     $120.00                 4      $35.00                 1
# 25534     $126.00                 1       $0.00                 1
# 26377     $170.00                 1       $0.00                 1
# 26649      $85.00                 2       $0.00                 1
# 26655     $150.00                 3     $150.00                 1
#
#       number_of_reviews review_scores_rating amenities_count
# 91                    9                 94.0              43
# 149                 404                 98.0              47
# 169                 125                 99.0              25
# 170                  87                 98.0              20
# 171                  63                 97.0              21
# ...                 ...                  ...             ...
# 25438                11                 95.0              39
# 25534                10                 98.0              28
# 26377                25                 94.0              24
# 26649                13                 91.0              28
# 26655                 6                100.0              46
#
# [104 rows x 26 columns]

# %%
# Is there a listing without a bedroom, bathroom and bed
df.query('beds == 0 and bedrooms == 0 and bathrooms == 0')
# Out:
# Empty DataFrame
# Columns: [id, host_since, host_is_superhost, host_identity_verified, country, latitude, longitude, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, has_availability, number_of_reviews, review_scores_rating, amenities_count]
# Index: []
#
# [0 rows x 26 columns]

# %%
df[(df['beds'] == 0) & (df['bedrooms'] == 0) & (df['bathrooms'] == 0)]
# Out:
# Empty DataFrame
# Columns: [id, host_since, host_is_superhost, host_identity_verified, country, latitude, longitude, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, has_availability, number_of_reviews, review_scores_rating, amenities_count]
# Index: []
#
# [0 rows x 26 columns]

# %%
df['has_availability']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 27065    1
# 27066    1
# 27067    1
# 27068    1
# 27069    1
# Name: has_availability, Length: 27070, dtype: int64

# %%
df['has_availability'].unique()
# Out:
# array([1])

# %%
df['has_availability'].std()
# Out:
# 0.0

# %%
df['has_availability'].var()
# Out:
# 0.0

# %%
df.columns
# Out:
# Index(['id', 'host_since', 'host_is_superhost', 'host_identity_verified',
#        'country', 'latitude', 'longitude', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'square_feet', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'has_availability', 'number_of_reviews', 'review_scores_rating',
#        'amenities_count'],
#       dtype='object')

# %%
df.drop('has_availability', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'host_since', 'host_is_superhost', 'host_identity_verified',
#        'country', 'latitude', 'longitude', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'square_feet', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'number_of_reviews', 'review_scores_rating', 'amenities_count'],
#       dtype='object')

# %%
df.describe(include=object)
# Out:
#        host_since host_is_superhost host_identity_verified    country  \
# count       27035             27035                  27035      27070
# unique       2590                 2                      2          1
# top      10/07/13                 f                      f  Australia
# freq          157             23616                  14323      27070
#
#        property_type        room_type  bed_type     price weekly_price  \
# count          27070            27070     27070     27070         3920
# unique            39                3         5       735          652
# top        Apartment  Entire home/apt  Real Bed  $150.00      $700.00
# freq           15921            16919     26858      1092          153
#
#        monthly_price security_deposit cleaning_fee extra_people
# count           2375            16722        19250        27070
# unique           650              272          328           99
# top       $2,000.00            $0.00       $50.00        $0.00
# freq             100             3191         2035        17933

# %%
df['host_is_superhost'].value_counts()
# Out:
# host_is_superhost
# f    23616
# t     3419
# Name: count, dtype: int64

# %%
df['host_identity_verified'].value_counts()
# Out:
# host_identity_verified
# f    14323
# t    12712
# Name: count, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# Australia    27070
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'host_since', 'host_is_superhost', 'host_identity_verified',
#        'country', 'latitude', 'longitude', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'square_feet', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'number_of_reviews', 'review_scores_rating', 'amenities_count'],
#       dtype='object')

# %%
df.drop("country", axis = 1, inplace =True)

# %%
df.columns
# Out:
# Index(['id', 'host_since', 'host_is_superhost', 'host_identity_verified',
#        'latitude', 'longitude', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'square_feet', 'price',
#        'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'number_of_reviews',
#        'review_scores_rating', 'amenities_count'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27070 entries, 0 to 27069
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      27070 non-null  int64
#  1   host_since              27035 non-null  object
#  2   host_is_superhost       27035 non-null  object
#  3   host_identity_verified  27035 non-null  object
#  4   latitude                27070 non-null  float64
#  5   longitude               27070 non-null  float64
#  6   property_type           27070 non-null  object
#  7   room_type               27070 non-null  object
#  8   accommodates            27070 non-null  int64
#  9   bathrooms               27048 non-null  float64
#  10  bedrooms                27062 non-null  float64
#  11  beds                    27037 non-null  float64
#  12  bed_type                27070 non-null  object
#  13  square_feet             256 non-null    float64
#  14  price                   27070 non-null  object
#  15  weekly_price            3920 non-null   object
#  16  monthly_price           2375 non-null   object
#  17  security_deposit        16722 non-null  object
#  18  cleaning_fee            19250 non-null  object
#  19  guests_included         27070 non-null  int64
#  20  extra_people            27070 non-null  object
#  21  number_of_reviews       27070 non-null  int64
#  22  review_scores_rating    19512 non-null  float64
#  23  amenities_count         27070 non-null  int64
# dtypes: float64(7), int64(5), object(12)
# memory usage: 5.2+ MB

# %%
df.describe(include=object)
# Out:
#        host_since host_is_superhost host_identity_verified property_type  \
# count       27035             27035                  27035         27070
# unique       2590                 2                      2            39
# top      10/07/13                 f                      f     Apartment
# freq          157             23616                  14323         15921
#
#               room_type  bed_type     price weekly_price monthly_price  \
# count             27070     27070     27070         3920          2375
# unique                3         5       735          652           650
# top     Entire home/apt  Real Bed  $150.00      $700.00     $2,000.00
# freq              16919     26858      1092          153           100
#
#        security_deposit cleaning_fee extra_people
# count             16722        19250        27070
# unique              272          328           99
# top              $0.00       $50.00        $0.00
# freq               3191         2035        17933

# %%
df.describe()
# Out:
#                  id      latitude     longitude  accommodates     bathrooms  \
# count  2.707000e+04  27070.000000  27070.000000  27070.000000  27048.000000
# mean   1.402672e+07    -33.862368    151.210667      3.383598      1.352337
# std    6.520952e+06      0.072260      0.079451      2.196864      0.664092
# min    1.115600e+04    -34.135212    150.644964      1.000000      0.000000
# 25%    9.083668e+06    -33.897603    151.184472      2.000000      1.000000
# 50%    1.544074e+07    -33.883064    151.223242      2.000000      1.000000
# 75%    2.015561e+07    -33.831850    151.264888      4.000000      1.500000
# max    2.270966e+07    -33.389728    151.339811     16.000000     10.000000
#
#            bedrooms          beds   square_feet  guests_included  \
# count  27062.000000  27037.000000    256.000000     27070.000000
# mean       1.614071      2.012169    421.453125         1.515146
# std        1.109725      1.526399   1573.511992         1.256044
# min        0.000000      0.000000      0.000000         1.000000
# 25%        1.000000      1.000000      0.000000         1.000000
# 50%        1.000000      1.000000      0.000000         1.000000
# 75%        2.000000      2.000000    282.500000         1.000000
# max       46.000000     29.000000  21528.000000        16.000000
#
#        number_of_reviews  review_scores_rating  amenities_count
# count       27070.000000          19512.000000     27070.000000
# mean           14.005689             93.412413        20.343517
# std            29.808917              9.354959        10.908119
# min             0.000000             20.000000         1.000000
# 25%             0.000000             90.000000        13.000000
# 50%             3.000000             96.000000        17.000000
# 75%            13.000000            100.000000        25.000000
# max           468.000000            100.000000       101.000000

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    16919
# Private room        9754
# Shared room          397
# Name: count, dtype: int64

# %%
df['room_type'].mode()
# Out:
# 0    Entire home/apt
# Name: room_type, dtype: object

# %%
df['bed_type'].value_counts()
# Out:
# bed_type
# Real Bed         26858
# Pull-out Sofa      109
# Futon               57
# Airbed              25
# Couch               21
# Name: count, dtype: int64

# %% [markdown]
# - The price column and the other columns having the amount in dollars are object column
# - They should be numerical columns
# - Let's convert them into float

# %%
df['price'].iloc[0]
# Out:
# '$65.00 '

# %%
df['price'].iloc[0].replace('$', '')
# Out:
# '65.00 '

# %%
df['price'].iloc[0].lstrip('$')
# Out:
# '65.00 '

# %%
df['price'].iloc[0].strip()
# Out:
# '$65.00'

# %%
df['price'].iloc[0].strip().replace('$', '')
# Out:
# '65.00'

# %%
float(df['price'].iloc[0].strip().replace('$', ''))
# Out:
# 65.0

# %%
def convert_price_to_float(price_in_str):
    return float(price_in_str.strip().replace('$', ''))

# %%
df['price'].apply(convert_price_to_float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df['price'].apply(convert_price_to_float)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[104], line 2, in convert_price_to_float(price_in_str)
#       1 def convert_price_to_float(price_in_str):
# ----> 2     return float(price_in_str.strip().replace('$', ''))
#
# ValueError: could not convert string to float: '1,045.00'

# %%
def convert_price_to_float(price_in_str):
    return float(price_in_str.strip().replace('$', '').replace(',', ''))

# %%
df['price'] = df['price'].apply(convert_price_to_float)

# %%
df['price']
# Out:
# 0         65.0
# 1         98.0
# 2        469.0
# 3         63.0
# 4         39.0
#          ...
# 27065    101.0
# 27066     40.0
# 27067    169.0
# 27068     98.0
# 27069    119.0
# Name: price, Length: 27070, dtype: float64

# %%
df['price'].describe()
# Out:
# count    27070.000000
# mean       209.278796
# std        304.336271
# min          0.000000
# 25%         80.000000
# 50%        135.000000
# 75%        229.000000
# max      12999.000000
# Name: price, dtype: float64

# %%
df[['weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee', 'extra_people']]
# Out:
#       weekly_price monthly_price security_deposit cleaning_fee extra_people
# 0              NaN           NaN              NaN          NaN       $0.00
# 1         $800.00            NaN           $0.00       $55.00      $395.00
# 2       $3,000.00            NaN         $900.00      $100.00       $40.00
# 3              NaN           NaN              NaN          NaN      $40.00
# 4              NaN           NaN              NaN          NaN       $0.00
# ...            ...           ...              ...          ...          ...
# 27065          NaN           NaN         $200.00        $0.00       $30.00
# 27066          NaN           NaN              NaN          NaN       $0.00
# 27067          NaN           NaN         $300.00       $80.00       $20.00
# 27068          NaN           NaN         $400.00      $120.00       $25.00
# 27069          NaN           NaN              NaN      $50.00        $0.00
#
# [27070 rows x 5 columns]

# %%
df[['weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee', 'extra_people']].isna().sum()
# Out:
# weekly_price        23150
# monthly_price       24695
# security_deposit    10348
# cleaning_fee         7820
# extra_people            0
# dtype: int64

# %%
df['cleaning_fee'] = df['cleaning_fee'].apply(convert_price_to_float)

# %%
df['cleaning_fee']
# Out:
# 0             NaN
# 1         $55.00
# 2        $100.00
# 3             NaN
# 4             NaN
#            ...
# 27065      $0.00
# 27066         NaN
# 27067     $80.00
# 27068    $120.00
# 27069     $50.00
# Name: cleaning_fee, Length: 27070, dtype: object

# %%
def convert_price_to_float(price_in_str):
    if isinstance(price_in_str, str):
        return float(price_in_str.strip().replace('$', '').replace(',', ''))
    else:
        return price_in_str

# %%
df['cleaning_fee'] = df['cleaning_fee'].apply(convert_price_to_float)

# %%
df['cleaning_fee']
# Out:
# 0          NaN
# 1         55.0
# 2        100.0
# 3          NaN
# 4          NaN
#          ...
# 27065      0.0
# 27066      NaN
# 27067     80.0
# 27068    120.0
# 27069     50.0
# Name: cleaning_fee, Length: 27070, dtype: float64

# %%
df.describe(include=object)
# Out:
#        host_since host_is_superhost host_identity_verified property_type  \
# count       27035             27035                  27035         27070
# unique       2590                 2                      2            39
# top      10/07/13                 f                      f     Apartment
# freq          157             23616                  14323         15921
#
#               room_type  bed_type weekly_price monthly_price security_deposit  \
# count             27070     27070         3920          2375            16722
# unique                3         5          652           650              272
# top     Entire home/apt  Real Bed     $700.00     $2,000.00            $0.00
# freq              16919     26858          153           100             3191
#
#        extra_people
# count         27070
# unique           99
# top          $0.00
# freq          17933

# %%
df['host_since']
# Out:
# 0        23/09/09
# 1        14/05/09
# 2        20/11/09
# 3        30/11/09
# 4        30/11/09
#            ...
# 27065    16/02/17
# 27066    12/01/18
# 27067    11/01/18
# 27068    13/01/18
# 27069    13/12/14
# Name: host_since, Length: 27070, dtype: object

# %%
df['host_since'].iloc[0]
# Out:
# '23/09/09'

# %%
# We can convert the df['host_since'] column to datetime format

# %%
pd.to_datetime(df['host_since'])
# Out:
# /var/folders/yv/_ddlvjkn6k11_jp7sl8jcy500000gn/T/ipykernel_7600/2993864240.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['host_since'])
# 0       2009-09-23
# 1       2009-05-14
# 2       2009-11-20
# 3       2009-11-30
# 4       2009-11-30
#            ...
# 27065   2017-02-16
# 27066   2018-12-01
# 27067   2018-11-01
# 27068   2018-01-13
# 27069   2014-12-13
# Name: host_since, Length: 27070, dtype: datetime64[ns]

# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
df['host_since'] = pd.to_datetime(df['host_since'])

# %%
df['host_since']
# Out:
# 0       2009-09-23
# 1       2009-05-14
# 2       2009-11-20
# 3       2009-11-30
# 4       2009-11-30
#            ...
# 27065   2017-02-16
# 27066   2018-12-01
# 27067   2018-11-01
# 27068   2018-01-13
# 27069   2014-12-13
# Name: host_since, Length: 27070, dtype: datetime64[ns]

# %% [markdown]
# # Check for null/Nan/missing values

# %%
df.isna().sum()
# Out:
# id                            0
# host_since                   35
# host_is_superhost            35
# host_identity_verified       35
# latitude                      0
# longitude                     0
# property_type                 0
# room_type                     0
# accommodates                  0
# bathrooms                    22
# bedrooms                      8
# beds                         33
# bed_type                      0
# square_feet               26814
# price                         0
# weekly_price              23150
# monthly_price             24695
# security_deposit          10348
# cleaning_fee               7820
# guests_included               0
# extra_people                  0
# number_of_reviews             0
# review_scores_rating       7558
# amenities_count               0
# dtype: int64

# %%
missing_vals = df.isna().sum()

# %%
missing_vals[missing_vals > 0]
# Out:
# host_since                   35
# host_is_superhost            35
# host_identity_verified       35
# bathrooms                    22
# bedrooms                      8
# beds                         33
# square_feet               26814
# weekly_price              23150
# monthly_price             24695
# security_deposit          10348
# cleaning_fee               7820
# review_scores_rating       7558
# dtype: int64

# %%
missing_vals[missing_vals > 0] / len(df) * 100
# Out:
# host_since                 0.129294
# host_is_superhost          0.129294
# host_identity_verified     0.129294
# bathrooms                  0.081271
# bedrooms                   0.029553
# beds                       0.121906
# square_feet               99.054304
# weekly_price              85.519025
# monthly_price             91.226450
# security_deposit          38.226819
# cleaning_fee              28.888068
# review_scores_rating      27.920207
# dtype: float64

# %%
len(df)
# Out:
# 27070

# %%
sns.heatmap(df.isna())
plt.show()

# %%
sns.heatmap(df.isna(), cmap='coolwarm')
plt.show()

# %%
sns.heatmap(df.isna(), cmap='viridis')
plt.show()
